# %%
import pandas as pd
import numpy as np
df = pd.read_csv('../DATA/fake_reg.csv')

# %%
import seaborn as sns
sns.pairplot(df)

# %%
from sklearn.model_selection import train_test_split
# Convert Pandas to Numpy for Keras

# Features
X = df[['feature1','feature2']].values

# Label
y = df['price'].values

# Split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=42)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (700, 2)
# (300, 2)
# (700,)
# (300,)

# %% [markdown]
# ### normalizing / scaling data

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### tenserflow 2.0 syntax

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
help(Sequential)
# Out:
# Help on class Sequential in module keras.engine.sequential:
#
# class Sequential(keras.engine.functional.Functional)
#  |  Sequential(layers=None, name=None)
#  |
#  |  `Sequential` groups a linear stack of layers into a `tf.keras.Model`.
#  |
#  |  `Sequential` provides training and inference features on this model.
#  |
#  |  Examples:
#  |
#  |  ```python
#  |  # Optionally, the first layer can receive an `input_shape` argument:
#  |  model = tf.keras.Sequential()
#  |  model.add(tf.keras.layers.Dense(8, input_shape=(16,)))
#  |  # Afterwards, we do automatic shape inference:
#  |  model.add(tf.keras.layers.Dense(4))
#  |
#  |  # This is identical to the following:
#  |  model = tf.keras.Sequential()
#  |  model.add(tf.keras.Input(shape=(16,)))
#  |  model.add(tf.keras.layers.Dense(8))
#  |
#  |  # Note that you can also omit the `input_shape` argument.
#  |  # In that case the model doesn't have any weights until the first call
# ...

# %% [markdown]
# ### creating a model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation

# %% [markdown]
# #### model as a list of array

# %%
model = Sequential()

model.add(Dense(2))
model.add(Dense(2))
model.add(Dense(2))

# %% [markdown]
# #### model adding in  layers one by one

# %%
model = Sequential()

model.add(Dense(2))
model.add(Dense(2))
model.add(Dense(2))

# %%
model = Sequential()

model.add(Dense(4, activation='relu'))
model.add(Dense(4, activation='relu'))
model.add(Dense(4, activation='relu'))

# final output node for prediction

model.add(Dense(1))
model.compile(optimizer='rmsprop',loss='mse')

# %% [markdown]
# ### Training

# %%
model.fit(X_train,y_train,epochs=250)
# Out:
# Epoch 1/250
# 22/22 [==============================] - 4s 5ms/step - loss: 256704.7500
# Epoch 2/250
# 22/22 [==============================] - 0s 4ms/step - loss: 256638.1250
# Epoch 3/250
# 22/22 [==============================] - 0s 3ms/step - loss: 256562.1719
# Epoch 4/250
# 22/22 [==============================] - 0s 3ms/step - loss: 256487.2969
# Epoch 5/250
# 22/22 [==============================] - 0s 3ms/step - loss: 256412.0000
# Epoch 6/250
# 22/22 [==============================] - 0s 4ms/step - loss: 256330.5781
# Epoch 7/250
# 22/22 [==============================] - 0s 3ms/step - loss: 256238.3594
# Epoch 8/250
# 22/22 [==============================] - 0s 3ms/step - loss: 256132.5000
# Epoch 9/250
# 22/22 [==============================] - 0s 3ms/step - loss: 256010.9531
# Epoch 10/250
# 22/22 [==============================] - 0s 3ms/step - loss: 255871.0781
# Epoch 11/250
# 22/22 [==============================] - 0s 3ms/step - loss: 255709.7656
# Epoch 12/250
# ...

# %% [markdown]
# ### Evaluation

# %%
model.history.history
# Out:
# {'loss': [256704.75,
#   256638.125,
#   256562.171875,
#   256487.296875,
#   256412.0,
#   256330.578125,
#   256238.359375,
#   256132.5,
#   256010.953125,
#   255871.078125,
#   255709.765625,
#   255527.75,
#   255323.765625,
#   255096.703125,
#   254845.296875,
#   254567.453125,
#   254262.65625,
#   253934.453125,
#   253574.171875,
#   253184.484375,
#   252758.53125,
#   252301.03125,
#   251807.015625,
#   251271.859375,
#   250697.078125,
#   250082.125,
#   249422.671875,
#   248717.296875,
#   247962.671875,
#   247155.765625,
#   246303.46875,
#   245393.546875,
#   244425.09375,
#   243403.5625,
#   242316.140625,
#   241174.625,
#   239962.1875,
#   238682.90625,
#   237342.46875,
#   235927.59375,
#   234445.078125,
#   232879.40625,
#   231249.578125,
#   229533.9375,
#   227743.46875,
#   225873.484375,
#   223918.109375,
#   221883.359375,
#   219747.765625,
#   217545.234375,
#   215239.765625,
#   212835.703125,
#   210352.15625,
#   207776.984375,
# ...

# %%
loss = model.history.history['loss']

# %%
sns.lineplot(x=range(len(loss)),y=loss)
plt.title("Training Loss per Epoch");

# %% [markdown]
# ### compare final evaluation(mse) training sety vs test set

# %%
model.metrics_names
# Out:
# ['loss']

# %%
training_score = model.evaluate(X_train,y_train,verbose=0)
test_score = model.evaluate(X_test,y_test,verbose=0)

# %%
training_score
# Out:
# 25.319473266601562

# %%
test_score
# Out:
# 25.8952579498291

# %%
test_prediction = model.predict(X_test)
# Out:
# 10/10 [==============================] - 0s 5ms/step

# %%
test_prediction
# Out:
# array([[405.46234],
#        [621.98553],
#        [590.6541 ],
#        [571.47095],
#        [367.8466 ],
#        [578.0883 ],
#        [515.0874 ],
#        [458.55963],
#        [548.65826],
#        [447.00397],
#        [610.3063 ],
#        [547.2375 ],
#        [419.2203 ],
#        [409.18964],
#        [648.68585],
#        [437.0073 ],
#        [507.1873 ],
#        [658.73206],
#        [660.9962 ],
#        [564.1434 ],
#        [335.34854],
#        [444.74026],
#        [383.1639 ],
#        [379.10416],
#        [565.5446 ],
#        [609.5345 ],
#        [531.66974],
#        [427.78375],
#        [654.0828 ],
#        [413.89044],
#        [442.2242 ],
#        [484.6664 ],
#        [438.26898],
#        [680.1743 ],
#        [424.28638],
#        [418.07864],
#        [500.53314],
#        [549.4379 ],
#        [509.65915],
#        [396.32233],
#        [616.91156],
#        [416.49237],
#        [602.90936],
#        [445.2792 ],
#        [501.41116],
# ...

# %%
pred_df = pd.DataFrame(y_test,columns=['test_y'])

# %%
y_test
# Out:
# array([402.29631873, 624.15619847, 582.4550663 , 578.58860646,
#        371.22410361, 584.38110772, 514.40564086, 464.11587006,
#        551.65009963, 451.8041724 , 613.95995262, 547.73198239,
#        428.31614877, 413.84178036, 654.83912076, 429.21452014,
#        512.04904895, 657.71868008, 674.31102047, 565.19184559,
#        338.0902386 , 450.9760715 , 375.13754715, 379.10982057,
#        562.05793604, 593.6677957 , 531.27754687, 423.65453319,
#        656.65474461, 412.90687671, 439.49653517, 488.78691774,
#        448.51914416, 685.21654079, 424.81078609, 418.45717839,
#        507.44318662, 550.14246248, 503.21614081, 397.88209319,
#        621.11885596, 411.57560703, 609.3840753 , 449.02606966,
#        503.51419982, 578.32901814, 664.50877632, 498.6284209 ,
#        316.9505926 , 478.35823792, 514.89474416, 374.19760282,
#        531.66193891, 405.40016562, 637.30962074, 482.55641188,
#        624.99250404, 624.24709206, 455.13953399, 484.46159148,
# ...

# %%
pred_df
# Out:
#          test_y
# 0    402.296319
# 1    624.156198
# 2    582.455066
# 3    578.588606
# 4    371.224104
# ..          ...
# 295  525.704657
# 296  502.909473
# 297  612.727910
# 298  417.569725
# 299  410.538250
#
# [300 rows x 1 columns]

# %%
test_prediction = pd.Series(test_prediction.reshape(300,))

# %%
test_prediction
# Out:
# 0      405.462341
# 1      621.985535
# 2      590.654114
# 3      571.470947
# 4      367.846588
#           ...
# 295    528.573792
# 296    515.842773
# 297    608.122314
# 298    416.682129
# 299    411.291992
# Length: 300, dtype: float32

# %%
pred_df = pd.concat([pred_df,test_prediction],axis=1)

# %%
pred_df
# Out:
#          test_y           0
# 0    402.296319  405.462341
# 1    624.156198  621.985535
# 2    582.455066  590.654114
# 3    578.588606  571.470947
# 4    371.224104  367.846588
# ..          ...         ...
# 295  525.704657  528.573792
# 296  502.909473  515.842773
# 297  612.727910  608.122314
# 298  417.569725  416.682129
# 299  410.538250  411.291992
#
# [300 rows x 2 columns]

# %%
pred_df.columns = ['test y', 'model_prediction']

# %%
pred_df
# Out:
#          test y  model_prediction
# 0    402.296319        405.462341
# 1    624.156198        621.985535
# 2    582.455066        590.654114
# 3    578.588606        571.470947
# 4    371.224104        367.846588
# ..          ...               ...
# 295  525.704657        528.573792
# 296  502.909473        515.842773
# 297  612.727910        608.122314
# 298  417.569725        416.682129
# 299  410.538250        411.291992
#
# [300 rows x 2 columns]

# %%
sns.scatterplot(x='test y',y='model_prediction',data=pred_df)
# Out:
# <AxesSubplot:xlabel='test y', ylabel='model_prediction'>

# %%
pred_df['Error'] = pred_df['test y'] - pred_df['model_prediction']
sns.distplot(pred_df['Error'])
# Out:
# C:\Users\qw\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Error', ylabel='Density'>

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
print(mean_absolute_error(pred_df['test y'],pred_df['model_prediction']))
print(mean_squared_error(pred_df['test y'],pred_df['model_prediction']))
# Out:
# 4.107659084513271
# 25.89526348741208

# %%
test_score
# Out:
# 25.8952579498291

# %%
#rmse
test_score**0.5
# Out:
# 5.088738345585191

# %% [markdown]
# ### prediction on brand new data set

# %%
new_gem = [[998,1000]]
#dont forget to scale
print(scaler.transform(new_gem))
new_gem = scaler.transform(new_gem)
print(model.predict(new_gem))
# Out:
# [[0.14117652 0.53968792]]
# 1/1 [==============================] - 0s 56ms/step
# [[420.4437]]
